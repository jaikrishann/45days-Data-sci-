# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(df["total_bill"])

# %%
sns.lineplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x ="total_bill", y ="tip",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.hist(df["total_bill"])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#catplot --- catogrical plot --- catogrical columns 
#relplot -- relational plot --- numerical columns -- lineplot and scatterplot

# %%
sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter")
plt.title("graph", fontsize= 20,color = "red")                   ##xlabel , ylabel
# Out:
# Text(0.5, 1.0, 'graph')

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="time")

# %%
# what is the meaning of hue?

sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="smoker")
plt.title("graph")

sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="size")
plt.title("graph")
# Out:
# Text(0.5, 1.0, 'graph')

# %%
sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="time",style='size')

# %%
sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="time",style='size',col="time")

# %%
sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="time",style='size',row="time")

# %%
sns.relplot(x = "total_bill", y = "tip", data= df, kind="scatter",hue="time",style='size',col="size")

# %%
#catplpot 
sns.catplot(x = "day", y = "total_bill", data= df, kind= "strip")

# %%
sns.catplot(x = "day", y = "total_bill", data= df, kind="swarm")

# %%
sns.catplot(x = "day", y = "total_bill", data= df, kind= "bar")

# %%
sns.catplot(x = "day", y = "total_bill", data= df, kind= "violin")

# %%
sns.catplot(x = "day", y = "total_bill", data= df, kind= "box")

# %%
sns.catplot(x = "day", y = "total_bill", data= df, kind= "boxen")

# %%
sns.catplot(x = "day", data= df, kind="count")

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Sample data
# data = {'category': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'A', 'B', ]}
# df = pd.DataFrame(data)

# # Create a count plot
# sns.countplot(x='category', data=df)

# # Show the plot
# plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
##outliers -- execption(kuch points jo diff behave karte hai from most of the data points)
##aapna ko outliers se deal karna padhta hai --- remove and scale aand transform

# %%
upper_limit = df["total_bill"].quantile(0.70)
sns.boxplot(df[df["total_bill"]<upper_limit]["total_bill"])
##quantile means intervall
# Out:
# <Axes: ylabel='total_bill'>

# %%
##scale and tranform 
q1 = np.percentile(df["total_bill"],25)
q2 = np.percentile(df["total_bill"],75)
q1,q2
# Out:
# (13.3475, 24.127499999999998)

# %%
IQR = q2-q1
IQR
# Out:
# 10.779999999999998

# %%
upperr_limit = q2 + 1.5 *IQR
lowerr_limit = q1 -1.5*IQR

upperr_limit,lowerr_limit
# Out:
# (40.29749999999999, -2.8224999999999945)

# %%
# outliers_free_bill = df[(df["total_bill"]<=upperr_limit) & df(df["total_bill"]>=lowerr_limit)]

# outliers_free_bill

# %%
# df[(df["total_bill"]>=upperr_limit) & df(df["total_bill"]>=lowerr_limit)]

# %%
outliers_free_bill= df[(df["total_bill"] >= lowerr_limit) & (df["total_bill"] <= upperr_limit)]

outliers_free_bill
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [235 rows x 7 columns]

# %%
sns.boxplot(outliers_free_bill['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>
